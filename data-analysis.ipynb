# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/game-of-thrones/character-predictions.csv
# /kaggle/input/game-of-thrones/battles.csv
# /kaggle/input/game-of-thrones/character-deaths.csv

# %% [markdown]
# To visualise the raw data in graphical,tabular forms,we have imported various python libraries such as numpy,pandas,matplotlib,seaborn etc...

# %%
data=pd.read_csv('../input/game-of-thrones/battles.csv')

# %% [markdown]
# The pandas fuction read_csv() reads in values, where the delimiter is a comma character.You can export a csv file in any modern office suite including Google Sheets.Use the following csv data as an example.if you want to export data from DataFrame or pandas
# By doing so the entire data in the data set is in our hands we would later use this data as we desire.

# %%
data
# Out:
#                                                  name  year  battle_number  \
# 0                          Battle of the Golden Tooth   298              1
# 1                         Battle at the Mummer's Ford   298              2
# 2                                  Battle of Riverrun   298              3
# 3                            Battle of the Green Fork   298              4
# 4                       Battle of the Whispering Wood   298              5
# 5                                 Battle of the Camps   298              6
# 6                                       Sack of Darry   298              7
# 7                               Battle of Moat Cailin   299              8
# 8                            Battle of Deepwood Motte   299              9
# 9                           Battle of the Stony Shore   299             10
# 10                         Battle of Torrhen's Square   299             11
# ...

# %% [markdown]
# Since the data set is csv file,we have got entire data in tabular form.

# %%
data.head()
# Out:
#                             name  year  battle_number  \
# 0     Battle of the Golden Tooth   298              1
# 1    Battle at the Mummer's Ford   298              2
# 2             Battle of Riverrun   298              3
# 3       Battle of the Green Fork   298              4
# 4  Battle of the Whispering Wood   298              5
#
#               attacker_king             defender_king attacker_1 attacker_2  \
# 0  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 1  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 2  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 3                Robb Stark  Joffrey/Tommen Baratheon      Stark        NaN
# 4                Robb Stark  Joffrey/Tommen Baratheon      Stark      Tully
#
#   attacker_3 attacker_4 defender_1  ... major_death  major_capture  \
# 0        NaN        NaN      Tully  ...         1.0            0.0
# ...

# %% [markdown]
# The head() function is used to get the first n (5 by default) rows. This function returns the first n(5 by default) rows for the object based on position. It is useful for quickly testing if your object has the right type of data in it.So that we came to know that our data is perfect!

# %%
data.tail()
# Out:
#                            name  year  battle_number  \
# 33  Second Seige of Storm's End   300             34
# 34         Siege of Dragonstone   300             35
# 35            Siege of Riverrun   300             36
# 36           Siege of Raventree   300             37
# 37          Siege of Winterfell   300             38
#
#                attacker_king             defender_king attacker_1 attacker_2  \
# 33  Joffrey/Tommen Baratheon         Stannis Baratheon  Baratheon        NaN
# 34  Joffrey/Tommen Baratheon         Stannis Baratheon  Baratheon        NaN
# 35  Joffrey/Tommen Baratheon                Robb Stark  Lannister       Frey
# 36  Joffrey/Tommen Baratheon                Robb Stark    Bracken  Lannister
# 37         Stannis Baratheon  Joffrey/Tommen Baratheon  Baratheon   Karstark
#
#    attacker_3 attacker_4 defender_1  ... major_death  major_capture  \
# 33        NaN        NaN  Baratheon  ...         0.0            0.0
# ...

# %% [markdown]
# Return the last n(5 by default) rows. This function returns last n(5 by default) rows from the object based on position. It is useful for quickly verifying data.Just re-verifying!!

# %%
data.columns
# Out:
# Index(['name', 'year', 'battle_number', 'attacker_king', 'defender_king',
#        'attacker_1', 'attacker_2', 'attacker_3', 'attacker_4', 'defender_1',
#        'defender_2', 'defender_3', 'defender_4', 'attacker_outcome',
#        'battle_type', 'major_death', 'major_capture', 'attacker_size',
#        'defender_size', 'attacker_commander', 'defender_commander', 'summer',
#        'location', 'region', 'note'],
#       dtype='object')

# %% [markdown]
# columns attribute return the column labels of the given Dataframe.We have got all the coloumns(Headings/Parameters) in our Data

# %%
data.shape
# Out:
# (38, 25)

# %% [markdown]
# The shape attribute of pandas stores the number of rows and columns as a tuple(number of rows, number of columns)We came to know that our data has 38 rows and 25 columns

# %%
data.dtypes.value_counts()
# Out:
# object     16
# float64     7
# int64       2
# dtype: int64

# %% [markdown]
# We have used the value_counts() function to get a Series containing counts of unique valuesNow,We know the number of unique values in our Data

# %%
data.isnull()
# Out:
#      name   year  battle_number  attacker_king  defender_king  attacker_1  \
# 0   False  False          False          False          False       False
# 1   False  False          False          False          False       False
# 2   False  False          False          False          False       False
# 3   False  False          False          False          False       False
# 4   False  False          False          False          False       False
# 5   False  False          False          False          False       False
# 6   False  False          False          False          False       False
# 7   False  False          False          False          False       False
# 8   False  False          False          False          False       False
# 9   False  False          False          False          False       False
# 10  False  False          False          False          False       False
# 11  False  False          False          False          False       False
# ...

# %% [markdown]
# This Function Returns a Boolean value that indicates whether an expression contains no valid data (Null).

# %%
data.describe()
# Out:
#              year  battle_number  defender_3  defender_4  major_death  \
# count   38.000000      38.000000         0.0         0.0    37.000000
# mean   299.105263      19.500000         NaN         NaN     0.351351
# std      0.689280      11.113055         NaN         NaN     0.483978
# min    298.000000       1.000000         NaN         NaN     0.000000
# 25%    299.000000      10.250000         NaN         NaN     0.000000
# 50%    299.000000      19.500000         NaN         NaN     0.000000
# 75%    300.000000      28.750000         NaN         NaN     1.000000
# max    300.000000      38.000000         NaN         NaN     1.000000
#
#        major_capture  attacker_size  defender_size     summer
# count      37.000000      24.000000      19.000000  37.000000
# mean        0.297297    9942.541667    6428.157895   0.702703
# std         0.463373   20283.092065    6225.182106   0.463373
# min         0.000000      20.000000     100.000000   0.000000
# ...

# %% [markdown]
# Pandas describe() is used to view some basic statistical details like percentile, mean, std,min,max,count....etc. of a data frame or a series of numeric valuesNow we have the values of various statistical parameters like mean,min,count,max,etc for every coloumn

# %%
data.boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# We have divided the data set into three quartiles using boxplot() function.This graph represents the minimum, maximum, median, first quartile and third quartile in the data set. It is also useful in comparing the distribution of data across data sets by drawing boxplots for each of them.

# %%
y=data["defender_size"]
x=data["attacker_size"]
plt.scatter(x, y)
plt.show()

# %% [markdown]
# A Scatter plot is a type of data visualization technique that shows the relationship between two numerical variables.Shall we add a scatter() plot into our EDA? SURE!!!By Calling the scatter() method on the plot member draws a plot between two variables or two columns of pandas DataFrame.Our scatterplot is between "attacker_size" and "defender_size".

# %%
data.max()
# Out:
# name             The Red Wedding
# year                         300
# battle_number                 38
# attacker_1                 Stark
# defender_3                   NaN
# defender_4                   NaN
# major_death                  1.0
# major_capture                1.0
# attacker_size           100000.0
# defender_size            20000.0
# summer                       1.0
# region           The Westerlands
# dtype: object

# %% [markdown]
# max() returns the maximum value in each coloumnHence,we've got the maximum values of each column in our data i.e., eight coloumnsNote: In case of strings,it returns maximum value based on their corresponding ASCII values

# %%
data.min()
# Out:
# name             Battle at the Mummer's Ford
# year                                     298
# battle_number                              1
# attacker_1                         Baratheon
# defender_3                               NaN
# defender_4                               NaN
# major_death                              0.0
# major_capture                            0.0
# attacker_size                           20.0
# defender_size                          100.0
# summer                                   0.0
# region                       Beyond the Wall
# dtype: object

# %% [markdown]
# min() returns the maximum value in each coloumnHence,we've got the minimum values of each column in our data i.e., eight coloumnsNote: In case of strings,it returns minimum value based on their corresponding ASCII values

# %%
data.hist()
# Out:
# array([[<AxesSubplot:title={'center':'year'}>,
#         <AxesSubplot:title={'center':'battle_number'}>,
#         <AxesSubplot:title={'center':'defender_3'}>],
#        [<AxesSubplot:title={'center':'defender_4'}>,
#         <AxesSubplot:title={'center':'major_death'}>,
#         <AxesSubplot:title={'center':'major_capture'}>],
#        [<AxesSubplot:title={'center':'attacker_size'}>,
#         <AxesSubplot:title={'center':'defender_size'}>,
#         <AxesSubplot:title={'center':'summer'}>]], dtype=object)

# %% [markdown]
# The hist() function in pyplot module of matplotlib library is used to plot a histogram.Here,we've got histograms between various parameters/coloumns

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x=data['attacker_king'], y=data['defender_king'])
# Out:
# <AxesSubplot:xlabel='attacker_king', ylabel='defender_king'>

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x=data['attacker_1'], y=data['defender_1'])
# Out:
# <AxesSubplot:xlabel='attacker_1', ylabel='defender_1'>

# %% [markdown]
# Scatter plots' primary uses are to observe and show relationships between two numeric variables.
# Here the scatter plot are between "attacker_king" and "defender_king". Another scatterplot is between "attacker_1" and "defender_1".

# %%
plt.figure(figsize=(10,10))
sns.barplot(x=data['battle_number'], y=data['region'])
plt.xlabel("")
plt.title("battle_number and region")
# Out:
# Text(0.5, 1.0, 'battle_number and region')

# %% [markdown]
# barplot() method. A barplot is basically used to aggregate the categorical data according to some methods and by default it's the mean. This is the barplot between "battle_number" and "region".

# %% [markdown]
# Here we cleaned the data and detect the null values and done visualization on data.
